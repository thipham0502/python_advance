# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import geopandas as gpd

# %%
# Đọc file schools.csv
schools = pd.read_csv('schools.csv')
schools.head()
# Out:
#    School ID                School Name     Street Address          City  \
# 0        496    A. Z. Kelley Elementary   5834 Pettus Road       Antioch
# 1        375      Alex Green Elementary    3921 Lloyd Road  Whites Creek
# 2        105           Amqui Elementary  319 Anderson Lane       Madison
# 3        460  Andrew Jackson Elementary       110 Shute Ln   Old Hickory
# 4        110        Antioch High School   1900 Hobson Pike       Antioch
#
#   State  ZIP Code   Phone Number  School State ID       School Level  \
# 0    TN     37013  (615)941-7535                1  Elementary School
# 1    TN     37189  (615)876-5105                5  Elementary School
# 2    TN     37115  (615)612-3678               10  Elementary School
# 3    TN     37138  (615)847-7317               15  Elementary School
# 4    TN     37013  (615)641-5400               20        High School
#
#   Lowest Grade Highest Grade   Latitude  Longitude  \
# 0     Grade P3       Grade 4  36.021817 -86.658848
# ...

# %%
plt.figure(figsize=(10,6))
plt.scatter(schools.Longitude,schools.Latitude, c = 'darkblue', marker = 'p')
plt.show()

# %%
bus_stops = pd.read_csv('public_art.csv')
bus_stops
# Out:
#                                                  Title  \
# 0                              [Cross Country Runners]
# 1                      [Fourth and Commerce Sculpture]
# 2                                  12th & Porter Mural
# 3                                    A Splash of Color
# 4                                 A Story of Nashville
# 5                             Aerial Innovations Mural
# 6                                  Airport Sun Project
# 7                                       Andrew Jackson
# 8                                                Angel
# 9                                         Anticipation
# 10                                          April Baby
# 11            Arial Triangle [from the Gravity Series]
# 12                                   Phillips Monument
# 13                                               Ariel
# 14                                    Athena Parthenos
# 15                                          Benedictio
# ...

# %%
plt.figure(figsize=(10,6))
plt.scatter(bus_stops.Longitude,bus_stops.Latitude, c = 'red', marker = 'p')

plt.scatter(schools.Longitude,schools.Latitude, c = 'darkblue', marker = 'p')
plt.show()

# %%
# Đọc file .shp (phải có file .shx đi kèm)
geo_df = gpd.read_file('stations.shp')
geo_df
# Out:
#                                         geometry
# 0   POINT (-77.12911152370515 38.79930767201779)
# 1   POINT (-77.16797018042666 38.76652189268992)
# 2   POINT (-77.01586821694521 38.88507235514479)
# 3   POINT (-77.01663895662587 38.89609031766317)
# 4     POINT (-77.00513941992737 38.885062500925)
# 5   POINT (-77.02807799718069 38.89831447321318)
# 6   POINT (-77.02191539042379 38.89831680979661)
# 7   POINT (-77.02191438038649 38.90643681495173)
# 8   POINT (-77.02749589294891 38.91700239924426)
# 9   POINT (-77.00741429219985 38.89776603923524)
# 10  POINT (-76.98851193260715 38.84565770287511)
# 11   POINT (-76.95626270945314 38.8513013835867)
# 12  POINT (-76.93187015895299 38.84396455441679)
# 13  POINT (-76.91146421773884 38.82644634832078)
# 14  POINT (-77.05366757406264 38.81414366728901)
# 15    POINT (-77.06081120854599 38.806586117248)
# 16  POINT (-77.07087438931458 38.80042544970124)
# 17    POINT (-77.075205789149 38.79391585290674)
# ...

# %%
# Read in the services district shapefile and look at the first few rows.
service_district = gpd.read_file('school_districts.geojson.txt')
service_district

service_district.loc[0, 'geometry']

# %%
service_district.loc[6, 'geometry']

# %%
plt.figure(figsize=(10,8))
plt.scatter(schools.Longitude,schools.Latitude)
plt.title('Nashville Schools and School Districts')
plt.show()

# %%
service_district.plot(column='district',figsize=(10,8))
plt.title('Nashville Schools and School Districts')
plt.show()

# %%
service_district.plot(column='district',figsize=(10,8),legend=True)
plt.title('Nashville Schools and School Districts')
plt.show()

# %%
service_district.plot(column='district',figsize=(10,8),legend=True)
plt.title('Nashville Schools and School Districts')
plt.scatter(schools.Longitude,schools.Latitude,color='k')
plt.title('Nashville Schools and School Districts')
plt.show()
