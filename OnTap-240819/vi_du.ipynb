# %%
import numpy as np
import pandas as pd

# %%
employees = pd.read_excel('employees.xls')

# %%
employees.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 107 entries, 0 to 106
# Data columns (total 11 columns):
# EMPLOYEE_ID       107 non-null int64
# FIRST_NAME        107 non-null object
# LAST_NAME         107 non-null object
# EMAIL             107 non-null object
# PHONE_NUMBER      107 non-null object
# HIRE_DATE         107 non-null object
# JOB_ID            107 non-null object
# SALARY            107 non-null int64
# COMMISSION_PCT    35 non-null float64
# MANAGER_ID        106 non-null float64
# DEPARTMENT_ID     106 non-null float64
# dtypes: float64(3), int64(2), object(6)
# memory usage: 9.3+ KB

# %%
employees.shape
# Out:
# (107, 11)

# %%
employees.head()
# Out:
#    EMPLOYEE_ID FIRST_NAME LAST_NAME     EMAIL  PHONE_NUMBER  \
# 0          100     Steven      King     SKING  515.123.4567
# 1          101      Neena   Kochhar  NKOCHHAR  515.123.4568
# 2          102        Lex   De Haan   LDEHAAN  515.123.4569
# 3          103  Alexander    Hunold   AHUNOLD  590.423.4567
# 4          104      Bruce     Ernst    BERNST  590.423.4568
#
#              HIRE_DATE   JOB_ID  SALARY  COMMISSION_PCT  MANAGER_ID  \
# 0  2003-06-17 00:00:00  AD_PRES   24000             NaN         NaN
# 1  2005-09-21 00:00:00    AD_VP   17000             NaN       100.0
# 2  2001-01-13 00:00:00    AD_VP   17000             NaN       100.0
# 3  2006-01-03 00:00:00  IT_PROG    9000             NaN       102.0
# 4  2007-05-21 00:00:00  IT_PROG    6000             NaN       103.0
#
#    DEPARTMENT_ID
# 0           90.0
# 1           90.0
# 2           90.0
# 3           60.0
# 4           60.0

# %%
departments = pd.read_excel('departments.xls')
# Out:
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero

# %%
departments
# Out:
#     DEPARTMENT_ID       DEPARTMENT_NAME  MANAGER_ID  LOCATION_ID
# 0              10        Administration       200.0         1700
# 1              20             Marketing       201.0         1800
# 2              30            Purchasing       114.0         1700
# 3              40       Human Resources       203.0         2400
# 4              50              Shipping       121.0         1500
# 5              60                    IT       103.0         1400
# 6              70      Public Relations       204.0         2700
# 7              80                 Sales       145.0         2500
# 8              90             Executive       100.0         1700
# 9             100               Finance       108.0         1700
# 10            110            Accounting       205.0         1700
# 11            120              Treasury         NaN         1700
# 12            130         Corporate Tax         NaN         1700
# ...

# %%
deps = departments[['DEPARTMENT_ID','DEPARTMENT_NAME']]
deps
# Out:
#     DEPARTMENT_ID       DEPARTMENT_NAME
# 0              10        Administration
# 1              20             Marketing
# 2              30            Purchasing
# 3              40       Human Resources
# 4              50              Shipping
# 5              60                    IT
# 6              70      Public Relations
# 7              80                 Sales
# 8              90             Executive
# 9             100               Finance
# 10            110            Accounting
# 11            120              Treasury
# 12            130         Corporate Tax
# 13            140    Control And Credit
# 14            150  Shareholder Services
# 15            160              Benefits
# 16            170         Manufacturing
# 17            180          Construction
# 18            190           Contracting
# 19            200            Operations
# 20            210            IT Support
# 21            220                   NOC
# ...

# %%
jobs = pd.read_excel('jobs.xls')
# Out:
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero

# %%
jobs
# Out:
#         JOB_ID                        JOB_TITLE  MIN_SALARY  MAX_SALARY
# 0   AC_ACCOUNT                Public Accountant        4200        9000
# 1       AC_MGR               Accounting Manager        8200       16000
# 2      AD_ASST         Administration Assistant        3000        6000
# 3      AD_PRES                        President       20080       40000
# 4        AD_VP    Administration Vice President       15000       30000
# 5   FI_ACCOUNT                       Accountant        4200        9000
# 6       FI_MGR                  Finance Manager        8200       16000
# 7       HR_REP   Human Resources Representative        4000        9000
# 8      IT_PROG                       Programmer        4000       10000
# 9       MK_MAN                Marketing Manager        9000       15000
# 10      MK_REP         Marketing Representative        4000        9000
# 11      PR_REP  Public Relations Representative        4500       10500
# ...

# %%
jobs = jobs[['JOB_ID','JOB_TITLE']]
jobs
# Out:
#         JOB_ID                        JOB_TITLE
# 0   AC_ACCOUNT                Public Accountant
# 1       AC_MGR               Accounting Manager
# 2      AD_ASST         Administration Assistant
# 3      AD_PRES                        President
# 4        AD_VP    Administration Vice President
# 5   FI_ACCOUNT                       Accountant
# 6       FI_MGR                  Finance Manager
# 7       HR_REP   Human Resources Representative
# 8      IT_PROG                       Programmer
# 9       MK_MAN                Marketing Manager
# 10      MK_REP         Marketing Representative
# 11      PR_REP  Public Relations Representative
# 12    PU_CLERK                 Purchasing Clerk
# 13      PU_MAN               Purchasing Manager
# 14      SA_MAN                    Sales Manager
# 15      SA_REP             Sales Representative
# 16    SH_CLERK                   Shipping Clerk
# 17    ST_CLERK                      Stock Clerk
# 18      ST_MAN                    Stock Manager

# %%
employees
# Out:
#      EMPLOYEE_ID   FIRST_NAME    LAST_NAME     EMAIL        PHONE_NUMBER  \
# 0            100       Steven         King     SKING        515.123.4567
# 1            101        Neena      Kochhar  NKOCHHAR        515.123.4568
# 2            102          Lex      De Haan   LDEHAAN        515.123.4569
# 3            103    Alexander       Hunold   AHUNOLD        590.423.4567
# 4            104        Bruce        Ernst    BERNST        590.423.4568
# 5            105        David       Austin   DAUSTIN        590.423.4569
# 6            106        Valli    Pataballa  VPATABAL        590.423.4560
# 7            107        Diana      Lorentz  DLORENTZ        590.423.5567
# 8            108        Nancy    Greenberg  NGREENBE        515.124.4569
# 9            109       Daniel       Faviet   DFAVIET        515.124.4169
# 10           110         John         Chen     JCHEN        515.124.4269
# 11           111       Ismael      Sciarra  ISCIARRA        515.124.4369
# ...

# %%
deps
# Out:
#     DEPARTMENT_ID       DEPARTMENT_NAME
# 0              10        Administration
# 1              20             Marketing
# 2              30            Purchasing
# 3              40       Human Resources
# 4              50              Shipping
# 5              60                    IT
# 6              70      Public Relations
# 7              80                 Sales
# 8              90             Executive
# 9             100               Finance
# 10            110            Accounting
# 11            120              Treasury
# 12            130         Corporate Tax
# 13            140    Control And Credit
# 14            150  Shareholder Services
# 15            160              Benefits
# 16            170         Manufacturing
# 17            180          Construction
# 18            190           Contracting
# 19            200            Operations
# 20            210            IT Support
# 21            220                   NOC
# ...

# %%
emp = pd.merge(employees, deps, on='DEPARTMENT_ID', how='left')

# %%
emp
# Out:
#      EMPLOYEE_ID   FIRST_NAME    LAST_NAME     EMAIL        PHONE_NUMBER  \
# 0            100       Steven         King     SKING        515.123.4567
# 1            101        Neena      Kochhar  NKOCHHAR        515.123.4568
# 2            102          Lex      De Haan   LDEHAAN        515.123.4569
# 3            103    Alexander       Hunold   AHUNOLD        590.423.4567
# 4            104        Bruce        Ernst    BERNST        590.423.4568
# 5            105        David       Austin   DAUSTIN        590.423.4569
# 6            106        Valli    Pataballa  VPATABAL        590.423.4560
# 7            107        Diana      Lorentz  DLORENTZ        590.423.5567
# 8            108        Nancy    Greenberg  NGREENBE        515.124.4569
# 9            109       Daniel       Faviet   DFAVIET        515.124.4169
# 10           110         John         Chen     JCHEN        515.124.4269
# 11           111       Ismael      Sciarra  ISCIARRA        515.124.4369
# ...

# %%
emp.shape
# Out:
# (107, 12)

# %%
emp = pd.merge(emp, jobs, on='JOB_ID', how='left')

# %%
emp.shape
# Out:
# (107, 13)

# %%
emp
# Out:
#      EMPLOYEE_ID   FIRST_NAME    LAST_NAME     EMAIL        PHONE_NUMBER  \
# 0            100       Steven         King     SKING        515.123.4567
# 1            101        Neena      Kochhar  NKOCHHAR        515.123.4568
# 2            102          Lex      De Haan   LDEHAAN        515.123.4569
# 3            103    Alexander       Hunold   AHUNOLD        590.423.4567
# 4            104        Bruce        Ernst    BERNST        590.423.4568
# 5            105        David       Austin   DAUSTIN        590.423.4569
# 6            106        Valli    Pataballa  VPATABAL        590.423.4560
# 7            107        Diana      Lorentz  DLORENTZ        590.423.5567
# 8            108        Nancy    Greenberg  NGREENBE        515.124.4569
# 9            109       Daniel       Faviet   DFAVIET        515.124.4169
# 10           110         John         Chen     JCHEN        515.124.4269
# 11           111       Ismael      Sciarra  ISCIARRA        515.124.4369
# ...

# %%
# rut trich theo dieu kien
emp[emp['SALARY']<5000]
# Out:
#      EMPLOYEE_ID FIRST_NAME    LAST_NAME     EMAIL  PHONE_NUMBER  \
# 5            105      David       Austin   DAUSTIN  590.423.4569
# 6            106      Valli    Pataballa  VPATABAL  590.423.4560
# 7            107      Diana      Lorentz  DLORENTZ  590.423.5567
# 15           115  Alexander         Khoo     AKHOO  515.127.4562
# 16           116     Shelli        Baida    SBAIDA  515.127.4563
# 17           117      Sigal       Tobias   STOBIAS  515.127.4564
# 18           118        Guy       Himuro   GHIMURO  515.127.4565
# 19           119      Karen   Colmenares  KCOLMENA  515.127.4566
# 25           125      Julia        Nayer    JNAYER  650.124.1214
# 26           126      Irene  Mikkilineni  IMIKKILI  650.124.1224
# 27           127      James       Landry   JLANDRY  650.124.1334
# 28           128     Steven       Markle   SMARKLE  650.124.1434
# 29           129      Laura       Bissot   LBISSOT  650.124.5234
# ...

# %%
emp[(emp['SALARY']>=5000) & (emp['SALARY']<=7000)]
# Out:
#      EMPLOYEE_ID FIRST_NAME LAST_NAME     EMAIL        PHONE_NUMBER  \
# 4            104      Bruce     Ernst    BERNST        590.423.4568
# 13           113       Luis      Popp     LPOPP        515.124.4567
# 23           123     Shanta   Vollman  SVOLLMAN        650.123.4234
# 24           124      Kevin   Mourgos  KMOURGOS        650.123.5234
# 55           155     Oliver   Tuvault  OTUVAULT  011.44.1344.486508
# 61           161     Sarath    Sewall   SSEWALL  011.44.1345.529268
# 65           165      David       Lee      DLEE  011.44.1346.529268
# 66           166     Sundar      Ande     SANDE  011.44.1346.629268
# 67           167       Amit     Banda    ABANDA  011.44.1346.729268
# 73           173    Sundita     Kumar    SKUMAR  011.44.1343.329268
# 78           178  Kimberely     Grant    KGRANT  011.44.1644.429263
# 79           179    Charles   Johnson  CJOHNSON  011.44.1644.429262
# 102          202        Pat       Fay      PFAY        603.123.6666
# ...

# %%
emp[['EMPLOYEE_ID','FIRST_NAME','COMMISSION_PCT']]
# Out:
#      EMPLOYEE_ID   FIRST_NAME  COMMISSION_PCT
# 0            100       Steven             NaN
# 1            101        Neena             NaN
# 2            102          Lex             NaN
# 3            103    Alexander             NaN
# 4            104        Bruce             NaN
# 5            105        David             NaN
# 6            106        Valli             NaN
# 7            107        Diana             NaN
# 8            108        Nancy             NaN
# 9            109       Daniel             NaN
# 10           110         John             NaN
# 11           111       Ismael             NaN
# 12           112  Jose Manuel             NaN
# 13           113         Luis             NaN
# 14           114          Den             NaN
# 15           115    Alexander             NaN
# 16           116       Shelli             NaN
# 17           117        Sigal             NaN
# 18           118          Guy             NaN
# ...

# %%
# cho biet cac nhan vien co hoa hong
emp[emp['COMMISSION_PCT'].notnull()]
# Out:
#     EMPLOYEE_ID   FIRST_NAME   LAST_NAME     EMAIL        PHONE_NUMBER  \
# 45          145         John     Russell   JRUSSEL  011.44.1344.429268
# 46          146        Karen    Partners  KPARTNER  011.44.1344.467268
# 47          147      Alberto   Errazuriz  AERRAZUR  011.44.1344.429278
# 48          148       Gerald   Cambrault  GCAMBRAU  011.44.1344.619268
# 49          149        Eleni     Zlotkey  EZLOTKEY  011.44.1344.429018
# 50          150        Peter      Tucker   PTUCKER  011.44.1344.129268
# 51          151        David   Bernstein  DBERNSTE  011.44.1344.345268
# 52          152        Peter        Hall     PHALL  011.44.1344.478968
# 53          153  Christopher       Olsen    COLSEN  011.44.1344.498718
# 54          154      Nanette   Cambrault  NCAMBRAU  011.44.1344.987668
# 55          155       Oliver     Tuvault  OTUVAULT  011.44.1344.486508
# 56          156      Janette        King     JKING  011.44.1345.429268
# ...

# %%
# cho biet cac nhan vien khong co hoa hong
emp[~emp['COMMISSION_PCT'].notnull()]
# Out:
#      EMPLOYEE_ID   FIRST_NAME    LAST_NAME     EMAIL  PHONE_NUMBER  \
# 0            100       Steven         King     SKING  515.123.4567
# 1            101        Neena      Kochhar  NKOCHHAR  515.123.4568
# 2            102          Lex      De Haan   LDEHAAN  515.123.4569
# 3            103    Alexander       Hunold   AHUNOLD  590.423.4567
# 4            104        Bruce        Ernst    BERNST  590.423.4568
# 5            105        David       Austin   DAUSTIN  590.423.4569
# 6            106        Valli    Pataballa  VPATABAL  590.423.4560
# 7            107        Diana      Lorentz  DLORENTZ  590.423.5567
# 8            108        Nancy    Greenberg  NGREENBE  515.124.4569
# 9            109       Daniel       Faviet   DFAVIET  515.124.4169
# 10           110         John         Chen     JCHEN  515.124.4269
# 11           111       Ismael      Sciarra  ISCIARRA  515.124.4369
# 12           112  Jose Manuel        Urman   JMURMAN  515.124.4469
# ...

# %%
# tinh toan thong ke
emp.describe()
# Out:
#        EMPLOYEE_ID        SALARY  COMMISSION_PCT  MANAGER_ID  DEPARTMENT_ID
# count   107.000000    107.000000       35.000000  106.000000     106.000000
# mean    153.000000   6461.831776        0.222857  124.764151      63.207547
# std      31.032241   3909.579731        0.085184   20.315395      20.910110
# min     100.000000   2100.000000        0.100000  100.000000      10.000000
# 25%     126.500000   3100.000000        0.150000  108.000000      50.000000
# 50%     153.000000   6200.000000        0.200000  122.000000      50.000000
# 75%     179.500000   8900.000000        0.300000  145.000000      80.000000
# max     206.000000  24000.000000        0.400000  205.000000     110.000000

# %%
emp['SALARY'].sum()
# Out:
# 691416

# %%
emp80 = emp[emp['DEPARTMENT_ID']==80]
emp80['SALARY'].sum()
# Out:
# 304500

# %%
emp[emp['DEPARTMENT_ID']==80]['SALARY'].sum() # tinh tong luong cac nhan vien phong 80
# Out:
# 304500

# %%
emp['SALARY'].median()
# Out:
# 6200.0

# %%
emp['SALARY'].quantile(0.25)
# Out:
# 3100.0

# %%
# sap xep tang theo luong
emp.sort_values(by=['SALARY'])
# Out:
#      EMPLOYEE_ID FIRST_NAME    LAST_NAME     EMAIL        PHONE_NUMBER  \
# 32           132         TJ        Olson   TJOLSON        650.124.8234
# 36           136      Hazel   Philtanker  HPHILTAN        650.127.1634
# 28           128     Steven       Markle   SMARKLE        650.124.1434
# 35           135         Ki          Gee      KGEE        650.127.1734
# 27           127      James       Landry   JLANDRY        650.124.1334
# 19           119      Karen   Colmenares  KCOLMENA        515.127.4566
# 31           131      James       Marlow   JAMRLOW        650.124.7234
# 40           140     Joshua        Patel    JPATEL        650.121.1834
# 91           191    Randall      Perkins  RPERKINS        650.505.4876
# 82           182     Martha     Sullivan  MSULLIVA        650.507.9878
# 44           144      Peter       Vargas   PVARGAS        650.121.2004
# 43           143    Randall        Matos    RMATOS        650.121.2874
# ...

# %%
emp.sort_values(by=['SALARY'], ascending=False)
# Out:
#      EMPLOYEE_ID FIRST_NAME    LAST_NAME     EMAIL        PHONE_NUMBER  \
# 0            100     Steven         King     SKING        515.123.4567
# 2            102        Lex      De Haan   LDEHAAN        515.123.4569
# 1            101      Neena      Kochhar  NKOCHHAR        515.123.4568
# 45           145       John      Russell   JRUSSEL  011.44.1344.429268
# 46           146      Karen     Partners  KPARTNER  011.44.1344.467268
# 101          201    Michael    Hartstein  MHARTSTE        515.123.5555
# 8            108      Nancy    Greenberg  NGREENBE        515.124.4569
# 105          205    Shelley      Higgins  SHIGGINS        515.123.8080
# 47           147    Alberto    Errazuriz  AERRAZUR  011.44.1344.429278
# 68           168       Lisa         Ozer     LOZER  011.44.1343.929268
# 48           148     Gerald    Cambrault  GCAMBRAU  011.44.1344.619268
# 74           174      Ellen         Abel     EABEL  011.44.1644.429267
# ...

# %%
emp_sort = emp.sort_values(by=['DEPARTMENT_ID','SALARY'], ascending=[True, False])

# %%
emp_sort
# Out:
#      EMPLOYEE_ID   FIRST_NAME   LAST_NAME     EMAIL        PHONE_NUMBER  \
# 100          200     Jennifer      Whalen   JWHALEN        515.123.4444
# 101          201      Michael   Hartstein  MHARTSTE        515.123.5555
# 102          202          Pat         Fay      PFAY        603.123.6666
# 14           114          Den    Raphaely  DRAPHEAL        515.127.4561
# 15           115    Alexander        Khoo     AKHOO        515.127.4562
# 16           116       Shelli       Baida    SBAIDA        515.127.4563
# 17           117        Sigal      Tobias   STOBIAS        515.127.4564
# 18           118          Guy      Himuro   GHIMURO        515.127.4565
# 19           119        Karen  Colmenares  KCOLMENA        515.127.4566
# 103          203        Susan      Mavris   SMAVRIS        515.123.7777
# 21           121         Adam       Fripp    AFRIPP        650.123.2234
# 20           120      Matthew       Weiss    MWEISS        650.123.1234
# ...

# %%
emp
# Out:
#      EMPLOYEE_ID   FIRST_NAME    LAST_NAME     EMAIL        PHONE_NUMBER  \
# 0            100       Steven         King     SKING        515.123.4567
# 1            101        Neena      Kochhar  NKOCHHAR        515.123.4568
# 2            102          Lex      De Haan   LDEHAAN        515.123.4569
# 3            103    Alexander       Hunold   AHUNOLD        590.423.4567
# 4            104        Bruce        Ernst    BERNST        590.423.4568
# 5            105        David       Austin   DAUSTIN        590.423.4569
# 6            106        Valli    Pataballa  VPATABAL        590.423.4560
# 7            107        Diana      Lorentz  DLORENTZ        590.423.5567
# 8            108        Nancy    Greenberg  NGREENBE        515.124.4569
# 9            109       Daniel       Faviet   DFAVIET        515.124.4169
# 10           110         John         Chen     JCHEN        515.124.4269
# 11           111       Ismael      Sciarra  ISCIARRA        515.124.4369
# ...

# %%
# emp = emp.sort_values(by=['DEPARTMENT_ID','SALARY'], ascending=[True, False])
# emp.sort_values(by=['DEPARTMENT_ID','SALARY'], ascending=[True, False])
# emp.sort_values(by=['DEPARTMENT_ID','SALARY'], ascending=[True, False], inplace=True)
# Out:
#      EMPLOYEE_ID   FIRST_NAME   LAST_NAME     EMAIL        PHONE_NUMBER  \
# 100          200     Jennifer      Whalen   JWHALEN        515.123.4444
# 101          201      Michael   Hartstein  MHARTSTE        515.123.5555
# 102          202          Pat         Fay      PFAY        603.123.6666
# 14           114          Den    Raphaely  DRAPHEAL        515.127.4561
# 15           115    Alexander        Khoo     AKHOO        515.127.4562
# 16           116       Shelli       Baida    SBAIDA        515.127.4563
# 17           117        Sigal      Tobias   STOBIAS        515.127.4564
# 18           118          Guy      Himuro   GHIMURO        515.127.4565
# 19           119        Karen  Colmenares  KCOLMENA        515.127.4566
# 103          203        Susan      Mavris   SMAVRIS        515.123.7777
# 21           121         Adam       Fripp    AFRIPP        650.123.2234
# 20           120      Matthew       Weiss    MWEISS        650.123.1234
# ...

# %%
# nhom du lieu va tinh toan
emp.groupby('DEPARTMENT_NAME').SALARY.sum()
# Out:
# DEPARTMENT_NAME
# Accounting           20308
# Administration        4400
# Executive            58000
# Finance              51608
# Human Resources       6500
# IT                   28800
# Marketing            19000
# Public Relations     10000
# Purchasing           24900
# Sales               304500
# Shipping            156400
# Name: SALARY, dtype: int64

# %%
emp.groupby('DEPARTMENT_NAME').SALARY.count()
# Out:
# DEPARTMENT_NAME
# Accounting           2
# Administration       1
# Executive            3
# Finance              6
# Human Resources      1
# IT                   5
# Marketing            2
# Public Relations     1
# Purchasing           6
# Sales               34
# Shipping            45
# Name: SALARY, dtype: int64

# %%
emp.groupby('DEPARTMENT_NAME', as_index=False).SALARY.sum()
# Out:
#      DEPARTMENT_NAME  SALARY
# 0         Accounting   20308
# 1     Administration    4400
# 2          Executive   58000
# 3            Finance   51608
# 4    Human Resources    6500
# 5                 IT   28800
# 6          Marketing   19000
# 7   Public Relations   10000
# 8         Purchasing   24900
# 9              Sales  304500
# 10          Shipping  156400

# %%
emp.groupby('DEPARTMENT_NAME').SALARY.agg(['sum','count','mean'])
# Out:
#                      sum  count          mean
# DEPARTMENT_NAME
# Accounting         20308      2  10154.000000
# Administration      4400      1   4400.000000
# Executive          58000      3  19333.333333
# Finance            51608      6   8601.333333
# Human Resources     6500      1   6500.000000
# IT                 28800      5   5760.000000
# Marketing          19000      2   9500.000000
# Public Relations   10000      1  10000.000000
# Purchasing         24900      6   4150.000000
# Sales             304500     34   8955.882353
# Shipping          156400     45   3475.555556

# %%
emp.groupby('DEPARTMENT_NAME').SALARY.agg(['sum','count','mean']).reset_index()
# Out:
#      DEPARTMENT_NAME     sum  count          mean
# 0         Accounting   20308      2  10154.000000
# 1     Administration    4400      1   4400.000000
# 2          Executive   58000      3  19333.333333
# 3            Finance   51608      6   8601.333333
# 4    Human Resources    6500      1   6500.000000
# 5                 IT   28800      5   5760.000000
# 6          Marketing   19000      2   9500.000000
# 7   Public Relations   10000      1  10000.000000
# 8         Purchasing   24900      6   4150.000000
# 9              Sales  304500     34   8955.882353
# 10          Shipping  156400     45   3475.555556

# %%
emp['NAM_VAO_LAM'] = pd.DatetimeIndex(emp['HIRE_DATE']).year

# %%
emp
# Out:
#      EMPLOYEE_ID   FIRST_NAME    LAST_NAME     EMAIL        PHONE_NUMBER  \
# 0            100       Steven         King     SKING        515.123.4567
# 1            101        Neena      Kochhar  NKOCHHAR        515.123.4568
# 2            102          Lex      De Haan   LDEHAAN        515.123.4569
# 3            103    Alexander       Hunold   AHUNOLD        590.423.4567
# 4            104        Bruce        Ernst    BERNST        590.423.4568
# 5            105        David       Austin   DAUSTIN        590.423.4569
# 6            106        Valli    Pataballa  VPATABAL        590.423.4560
# 7            107        Diana      Lorentz  DLORENTZ        590.423.5567
# 8            108        Nancy    Greenberg  NGREENBE        515.124.4569
# 9            109       Daniel       Faviet   DFAVIET        515.124.4169
# 10           110         John         Chen     JCHEN        515.124.4269
# 11           111       Ismael      Sciarra  ISCIARRA        515.124.4369
# ...

# %%
emp.groupby('NAM_VAO_LAM', as_index=False).EMPLOYEE_ID.count()
# Out:
#    NAM_VAO_LAM  EMPLOYEE_ID
# 0         2001            1
# 1         2002            7
# 2         2003            6
# 3         2004           10
# 4         2005           29
# 5         2006           24
# 6         2007           19
# 7         2008           11

# %%
emp_tax = emp[['EMPLOYEE_ID','FIRST_NAME','LAST_NAME','SALARY']]
emp_tax
# Out:
#      EMPLOYEE_ID   FIRST_NAME    LAST_NAME  SALARY
# 0            100       Steven         King   24000
# 1            101        Neena      Kochhar   17000
# 2            102          Lex      De Haan   17000
# 3            103    Alexander       Hunold    9000
# 4            104        Bruce        Ernst    6000
# 5            105        David       Austin    4800
# 6            106        Valli    Pataballa    4800
# 7            107        Diana      Lorentz    4200
# 8            108        Nancy    Greenberg   12008
# 9            109       Daniel       Faviet    9000
# 10           110         John         Chen    8200
# 11           111       Ismael      Sciarra    7700
# 12           112  Jose Manuel        Urman    7800
# 13           113         Luis         Popp    6900
# 14           114          Den     Raphaely   11000
# 15           115    Alexander         Khoo    3100
# 16           116       Shelli        Baida    2900
# ...

# %%
emp_tax['TAX'] = emp_tax['SALARY'].map(lambda x: x*0.08)
# Out:
# c:\program files\python36\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
emp_tax
# Out:
#      EMPLOYEE_ID   FIRST_NAME    LAST_NAME  SALARY      TAX
# 0            100       Steven         King   24000  1920.00
# 1            101        Neena      Kochhar   17000  1360.00
# 2            102          Lex      De Haan   17000  1360.00
# 3            103    Alexander       Hunold    9000   720.00
# 4            104        Bruce        Ernst    6000   480.00
# 5            105        David       Austin    4800   384.00
# 6            106        Valli    Pataballa    4800   384.00
# 7            107        Diana      Lorentz    4200   336.00
# 8            108        Nancy    Greenberg   12008   960.64
# 9            109       Daniel       Faviet    9000   720.00
# 10           110         John         Chen    8200   656.00
# 11           111       Ismael      Sciarra    7700   616.00
# 12           112  Jose Manuel        Urman    7800   624.00
# 13           113         Luis         Popp    6900   552.00
# 14           114          Den     Raphaely   11000   880.00
# ...

# %%
def tax_function(salary):
    return salary*0.08

# %%
emp_tax['TAX'] = emp_tax['SALARY'].map(lambda x: tax_function(x))
emp_tax
# Out:
# c:\program files\python36\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#      EMPLOYEE_ID   FIRST_NAME    LAST_NAME  SALARY      TAX
# 0            100       Steven         King   24000  1920.00
# 1            101        Neena      Kochhar   17000  1360.00
# 2            102          Lex      De Haan   17000  1360.00
# 3            103    Alexander       Hunold    9000   720.00
# 4            104        Bruce        Ernst    6000   480.00
# 5            105        David       Austin    4800   384.00
# 6            106        Valli    Pataballa    4800   384.00
# 7            107        Diana      Lorentz    4200   336.00
# ...

# %%
emp_tax = emp[['EMPLOYEE_ID','FIRST_NAME','LAST_NAME','SALARY']]
emp_tax['TAX'] = emp_tax['SALARY'].apply(tax_function)
# Out:
# c:\program files\python36\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
emp_tax
# Out:
#      EMPLOYEE_ID   FIRST_NAME    LAST_NAME  SALARY      TAX
# 0            100       Steven         King   24000  1920.00
# 1            101        Neena      Kochhar   17000  1360.00
# 2            102          Lex      De Haan   17000  1360.00
# 3            103    Alexander       Hunold    9000   720.00
# 4            104        Bruce        Ernst    6000   480.00
# 5            105        David       Austin    4800   384.00
# 6            106        Valli    Pataballa    4800   384.00
# 7            107        Diana      Lorentz    4200   336.00
# 8            108        Nancy    Greenberg   12008   960.64
# 9            109       Daniel       Faviet    9000   720.00
# 10           110         John         Chen    8200   656.00
# 11           111       Ismael      Sciarra    7700   616.00
# 12           112  Jose Manuel        Urman    7800   624.00
# 13           113         Luis         Popp    6900   552.00
# 14           114          Den     Raphaely   11000   880.00
# ...

# %%
emp_tax['TAX'] = emp_tax['SALARY'].apply(lambda x: x*0.08)
# Out:
# c:\program files\python36\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
emp_tax
# Out:
#      EMPLOYEE_ID   FIRST_NAME    LAST_NAME  SALARY      TAX
# 0            100       Steven         King   24000  1920.00
# 1            101        Neena      Kochhar   17000  1360.00
# 2            102          Lex      De Haan   17000  1360.00
# 3            103    Alexander       Hunold    9000   720.00
# 4            104        Bruce        Ernst    6000   480.00
# 5            105        David       Austin    4800   384.00
# 6            106        Valli    Pataballa    4800   384.00
# 7            107        Diana      Lorentz    4200   336.00
# 8            108        Nancy    Greenberg   12008   960.64
# 9            109       Daniel       Faviet    9000   720.00
# 10           110         John         Chen    8200   656.00
# 11           111       Ismael      Sciarra    7700   616.00
# 12           112  Jose Manuel        Urman    7800   624.00
# 13           113         Luis         Popp    6900   552.00
# 14           114          Den     Raphaely   11000   880.00
# ...

# %%
emp_tax['NAME'] = emp_tax.apply(lambda x: x['FIRST_NAME']+', '+x['LAST_NAME'], axis=1)
# Out:
# c:\program files\python36\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
emp_tax
# Out:
#      EMPLOYEE_ID   FIRST_NAME    LAST_NAME  SALARY      TAX  \
# 0            100       Steven         King   24000  1920.00
# 1            101        Neena      Kochhar   17000  1360.00
# 2            102          Lex      De Haan   17000  1360.00
# 3            103    Alexander       Hunold    9000   720.00
# 4            104        Bruce        Ernst    6000   480.00
# 5            105        David       Austin    4800   384.00
# 6            106        Valli    Pataballa    4800   384.00
# 7            107        Diana      Lorentz    4200   336.00
# 8            108        Nancy    Greenberg   12008   960.64
# 9            109       Daniel       Faviet    9000   720.00
# 10           110         John         Chen    8200   656.00
# 11           111       Ismael      Sciarra    7700   616.00
# 12           112  Jose Manuel        Urman    7800   624.00
# 13           113         Luis         Popp    6900   552.00
# 14           114          Den     Raphaely   11000   880.00
# ...

# %%
emp_tax[['SALARY']].apply(sum, axis=0)
# Out:
# SALARY    691416
# dtype: int64
