# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %%
iris = sb.load_dataset('iris')

# %%
sb.scatterplot(x="petal_length", y="petal_width", data=iris)

# %%
sb.scatterplot(x="petal_length", y="petal_width", data=iris, hue='species')

# %%
sb.scatterplot(x="petal_length", y="petal_width", data=iris, hue='species', style='species')
